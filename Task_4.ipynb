# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 12 styles in matplotlib

# %%
Company_1=[24,35,76,55,77,33,88]
Company_2=[45,67,89,34,86,9,2]
days=[2001,2002,2003,2004,2005,2006,2007]
plt.plot(days,Company_1,label="Company_1",color="Black")
plt.plot(days,Company_2,label="Company_2",color="#EE27F5")
plt.xlabel("Years")
plt.ylabel("Veg Thalis sold")
plt.title("Veg Thalis served in 7 days")
plt.legend()
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
Company_1=[24,35,76,55,77,33,88]
Company_2=[45,67,89,34,86,9,2]
days=[2001,2002,2003,2004,2005,2006,2007]
plt.style.use("seaborn-v0_8-deep")
plt.figure(figsize=(10,6))
plt.plot(days,Company_1,label="Company_1")
plt.plot(days,Company_2,label="Company_2")
plt.xlabel("Years")
plt.ylabel("Veg Thalis sold")
plt.title("Veg Thalis served in 7 days")
plt.legend()
plt.show()

# %%
Company_1=[24,35,76,55,77,33,88]
Company_2=[45,67,89,34,86,9,2]
days=[2001,2002,2003,2004,2005,2006,2007]
plt.style.use("Solarize_Light2")
plt.figure(figsize=(10,6))
plt.plot(days,Company_1,label="Company_1")
plt.plot(days,Company_2,label="Company_2")
plt.xlabel("Years")
plt.ylabel("Veg Thalis sold")
plt.title("Veg Thalis served in 7 days")
plt.legend()
plt.show()

# %%
Company_1=[24,35,76,55,77,33,88]
Company_2=[45,67,89,34,86,9,2]
days=[2001,2002,2003,2004,2005,2006,2007]
plt.style.use("seaborn-v0_8-notebook")
plt.figure(figsize=(10,6))
plt.plot(days,Company_1,label="Company_1")
plt.plot(days,Company_2,label="Company_2")
plt.xlabel("Years")
plt.ylabel("Veg Thalis sold")
plt.title("Veg Thalis served in 7 days")
plt.legend()
plt.show()

# %%
Company_1=[24,35,76,55,77,33,88]
Company_2=[45,67,89,34,86,9,2]
days=[2001,2002,2003,2004,2005,2006,2007]
plt.style.use("_classic_test_patch")
plt.figure(figsize=(10,6))
plt.plot(days,Company_1,label="Company_1")
plt.plot(days,Company_2,label="Company_2")
plt.xlabel("Years")
plt.ylabel("Veg Thalis sold")
plt.title("Veg Thalis served in 7 days")
plt.legend()
plt.show()

# %%
Company_1=[24,35,76,55,77,33,88]
Company_2=[45,67,89,34,86,9,2]
days=[2001,2002,2003,2004,2005,2006,2007]
plt.style.use("ggplot")
plt.figure(figsize=(10,6))
plt.plot(days,Company_1,label="Company_1")
plt.plot(days,Company_2,label="Company_2")
plt.xlabel("Years")
plt.ylabel("Veg Thalis sold")
plt.title("Veg Thalis served in 7 days")
plt.legend()
plt.show()

# %%
Company_1=[24,35,76,55,77,33,88]
Company_2=[45,67,89,34,86,9,2]
days=[2001,2002,2003,2004,2005,2006,2007]
plt.style.use("seaborn-v0_8-darkgrid")
plt.figure(figsize=(10,6))
plt.plot(days,Company_1,label="Company_1")
plt.plot(days,Company_2,label="Company_2")
plt.xlabel("Years")
plt.ylabel("Veg Thalis sold")
plt.title("Veg Thalis served in 7 days")
plt.legend()
plt.show()

# %%
Company_1=[24,35,76,55,77,33,88]
Company_2=[45,67,89,34,86,9,2]
days=[2001,2002,2003,2004,2005,2006,2007]
plt.style.use("fivethirtyeight")
plt.figure(figsize=(10,6))
plt.plot(days,Company_1,label="Company_1")
plt.plot(days,Company_2,label="Company_2")
plt.xlabel("Years")
plt.ylabel("Veg Thalis sold")
plt.title("Veg Thalis served in 7 days")
plt.legend()
plt.show()

# %%
Company_1=[24,35,76,55,77,33,88]
Company_2=[45,67,89,34,86,9,2]
days=[2001,2002,2003,2004,2005,2006,2007]
plt.style.use("petroff10")
plt.figure(figsize=(10,6))
plt.plot(days,Company_1,label="Company_1")
plt.plot(days,Company_2,label="Company_2")
plt.xlabel("Years")
plt.ylabel("Veg Thalis sold")
plt.title("Veg Thalis served in 7 days")
plt.legend()
plt.show()

# %%
Company_1=[24,35,76,55,77,33,88]
Company_2=[45,67,89,34,86,9,2]
days=[2001,2002,2003,2004,2005,2006,2007]
plt.style.use("tableau-colorblind10")
plt.figure(figsize=(10,6))
plt.plot(days,Company_1,label="Company_1")
plt.plot(days,Company_2,label="Company_2")
plt.xlabel("Years")
plt.ylabel("Veg Thalis sold")
plt.title("Veg Thalis served in 7 days")
plt.legend()
plt.show()

# %%
Company_1=[24,35,76,55,77,33,88]
Company_2=[45,67,89,34,86,9,2]
days=[2001,2002,2003,2004,2005,2006,2007]
plt.style.use("fast")
plt.figure(figsize=(10,6))
plt.plot(days,Company_1,label="Company_1")
plt.plot(days,Company_2,label="Company_2")
plt.xlabel("Years")
plt.ylabel("Veg Thalis sold")
plt.title("Veg Thalis served in 7 days")
plt.legend()
plt.show()

# %%
Company_1=[24,35,76,55,77,33,88]
Company_2=[45,67,89,34,86,9,2]
days=[2001,2002,2003,2004,2005,2006,2007]
plt.style.use("bmh")
plt.figure(figsize=(10,6))
plt.plot(days,Company_1,label="Company_1")
plt.plot(days,Company_2,label="Company_2")
plt.xlabel("Years")
plt.ylabel("Veg Thalis sold")
plt.title("Veg Thalis served in 7 days")
plt.legend()
plt.show()

# %%
Company_1=[24,35,76,55,77,33,88]
Company_2=[45,67,89,34,86,9,2]
days=[2001,2002,2003,2004,2005,2006,2007]
plt.style.use("seaborn-v0_8-muted")
plt.figure(figsize=(10,6))
plt.plot(days,Company_1,label="Company_1")
plt.plot(days,Company_2,label="Company_2")
plt.xlabel("Years")
plt.ylabel("Veg Thalis sold")
plt.title("Veg Thalis served in 7 days")
plt.legend()
plt.show()
